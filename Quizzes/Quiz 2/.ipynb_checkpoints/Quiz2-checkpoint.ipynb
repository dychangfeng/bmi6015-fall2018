# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p style="text-align: center;">
# **BMI 6015, Fall 2018
# Quiz-2: Applied Keras and Sklearn Concepts
# Release Date: 11-21-2018
# Duration: 60 minutes
# Marks: 100 points**
# </p>
#
#
# **Instructions**
#
# 1. The quiz will be uploading in the GitHub at 5:00 pm.
# 2. The student will download it, and the instructor will describe the quiz questions when asked by the student.
# 3. The student should comment on each solution step to illustrate the step objective.
# 4. The solutions should be written in a Jupyter notebook.
# 5. After finishing the quiz, the student should upload the quiz notebook in the canvas quiz speedgrader. The notebook name is the student name.
# 6. While the quiz is open book/notes/computer, no chatting or exchanging information through the internet is allowed.
# 7. The student can run the code in the server or the local machine.

# %% [markdown]
# **Student Name:**

# %% [markdown]
# ### Question 1 :40 Marks
#
# ##### If the student answer has any unnecessary step, that will penalize your answer by a 5-mark deduction for each unnecessary step.
#
# **Use Fashion-MNIST database of fashion articles dataset(keras.datasets) and Keras to develop a convolutional neural network with the  following model summary to answer the below requirements: **
#
# ![image.png](attachment:image.png)
#
#
# **A) Do data pre-processing steps, such as splitting, scaling, and encoding. (10 marks) **
#     - The validation split = 20% of the training data.
#
#
# **B) Develop the model: (20 Marks) **
#     - The filter size is 4x4.
#     - The max-pool size is 2x2.
#     - The number of epochs is 7 and the batch size is 32.
#
#
# **C) Report the results of the training/validation at each epoch and the testing datasets and check if the model is overfitted. If over-fitted, describe why? and select the number of epochs before the occurrence of overfitting. (10 marks) **

# %% [markdown]
# ### Question 2 :60 Marks
#
# ##### If the student answer will has any unnecessary step, that will penalize your answer by a 5-mark deduction for each unnecessary step.
#
# **Use the dataset (AU.csv) in your quiz folder and Keras to develop a fully-connected neural netwrok with the following specifications to answer the below requirements: **
#
#     - The number of hidden layers are 2 with 64 nodes for each layer.
#     - An input and output layers.
#     - Any other hyper-parameter selection per to the student decision.
#
#
# **A) Do data pre-processing steps, such as splitting, scaling, and encoding. (15 marks) **
#
# **B) Develop the model. (40 marks) **
#
# **C) Report the results of the training/validation at each epoch and the testing datasets and check if the model is overfitted. If over-fitted, select the number of epochs before the occurrence of overfitting. (5 marks) **
#
#
#
# ***The data of this question was downloaded from UC Irvine Machine Learning Repository***
